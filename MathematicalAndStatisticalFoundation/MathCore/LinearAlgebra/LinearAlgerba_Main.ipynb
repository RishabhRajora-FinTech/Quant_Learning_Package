# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabhRajora-FinTech/Quant_Learning_Package/blob/main/MathematicalAndStatisticalFoundation/MathCore/LinearAlgebra/LinearAlgerba_Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📐 Linear Algebra with Python
# **LinearAlgebra_Main** · NumPy · SciPy
#
# ---
#
# This notebook covers the **fundamentals of linear algebra** implemented in Python using `numpy` and `numpy.linalg`. Each section builds on the last — from basic vector operations to matrix decompositions.
#
# ## Prerequisites
# - Python 3.8+ with `numpy` and `matplotlib` installed
# - Basic familiarity with Python syntax
#
# ---
#
# ## Topics Covered
#
# | # | Topic | Key Functions |
# |---|-------|---------------|
# | 01 | **Vectors & Spaces** | `np.array()`, `np.zeros()`, `np.ones()` |
# | 02 | **Vector Operations** | `np.dot()`, `np.cross()`, `np.linalg.norm()` |
# | 03 | **Matrices & Types** | `np.eye()`, `np.diag()`, `.shape` |
# | 04 | **Matrix Multiplication** | `@`, `np.matmul()` |
# | 05 | **Transpose & Inverse** | `.T`, `np.linalg.inv()` |
# | 06 | **Determinants & Rank** | `np.linalg.det()`, `np.linalg.matrix_rank()` |
# | 07 | **Solving Ax = b** | `np.linalg.solve()` |
# | 08 | **Eigenvalues & Eigenvectors** | `np.linalg.eig()` |
# | 09 | **SVD Decomposition** | `np.linalg.svd()` |
# | 10 | **Practical Applications** | PCA, Least Squares |
#
# ---
#
# ## Key Formulas
#
# **Dot Product:**
#
# $$\vec{a} \cdot \vec{b} = \sum_{i=1}^{n} a_i b_i = \|a\| \|b\| \cos\theta$$
#
# **Matrix Multiplication:**
#
# $$C_{ij} = \sum_{k=1}^{n} A_{ik} B_{kj}$$
#
# **Eigenvalue Equation:**
#
# $$A\vec{v} = \lambda\vec{v}$$
#
# **SVD Decomposition:**
#
# $$A = U \Sigma V^T$$
#
# ---
#
# > 💡 **Tip:** Run each cell in order. Use `Shift + Enter` to execute and move to the next cell.
