# %% [markdown]
# <a href="https://colab.research.google.com/github/RishabhRajora-FinTech/Quant_Learning_Package/blob/main/MathematicalAndStatisticalFoundation/MathCore/LinearAlgebra/LinearAlgerba_Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

display(HTML("""
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>LinearAlgebra_Main</title>
<link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;500;600&family=Source+Sans+3:wght@300;400;600&display=swap" rel="stylesheet">
<style>
  :root {
    --bg: #0d1117;
    --surface: #161b22;
    --cell: #1c2128;
    --border: #30363d;
    --border-active: #58a6ff;
    --text: #e6edf3;
    --text-dim: #8b949e;
    --text-muted: #484f58;
    --blue: #58a6ff;
    --green: #3fb950;
    --purple: #bc8cff;
    --orange: #d29922;
    --red: #f85149;
    --cyan: #39d2c0;
    --mono: 'IBM Plex Mono', monospace;
    --sans: 'Source Sans 3', sans-serif;
  }
  * { margin: 0; padding: 0; box-sizing: border-box; }
  body { background: var(--bg); color: var(--text); font-family: var(--sans); }

  .nb {
    max-width: 900px;
    margin: 0 auto;
    padding: 32px 20px 80px;
  }

  /* ── Toolbar ── */
  .toolbar {
    display: flex;
    align-items: center;
    justify-content: space-between;
    background: var(--surface);
    border: 1px solid var(--border);
    border-bottom: none;
    border-radius: 8px 8px 0 0;
    padding: 8px 16px;
    font-family: var(--mono);
    font-size: 12px;
    color: var(--text-muted);
  }
  .toolbar .filename {
    color: var(--text-dim);
    font-weight: 500;
  }
  .toolbar .kernel {
    display: flex; align-items: center; gap: 6px;
  }
  .toolbar .kernel .dot {
    width: 7px; height: 7px;
    background: var(--green);
    border-radius: 50%;
    animation: pulse 2s infinite;
  }
  @keyframes pulse { 0%,100%{opacity:1} 50%{opacity:.35} }

  /* ── Cell ── */
  .cell {
    border: 1px solid var(--border);
    border-top: none;
    border-radius: 0 0 8px 8px;
    overflow: hidden;
  }

  .cell-header {
    display: flex;
    align-items: center;
    justify-content: space-between;
    background: var(--surface);
    padding: 5px 16px;
    border-bottom: 1px solid var(--border);
    font-family: var(--mono);
    font-size: 11px;
    color: var(--text-muted);
  }
  .cell-header .tag {
    background: rgba(88,166,255,0.1);
    color: var(--blue);
    padding: 2px 8px;
    border-radius: 4px;
    font-size: 10px;
    letter-spacing: .5px;
  }
  .cell-header .run {
    color: var(--green);
  }

  /* ── Markdown area ── */
  .md-body {
    background: var(--cell);
    padding: 28px 28px 24px;
    line-height: 1.75;
    font-size: 15px;
    color: var(--text-dim);
  }
  .md-body h1 {
    font-family: var(--sans);
    font-weight: 600;
    font-size: 22px;
    color: var(--text);
    margin-bottom: 6px;
    display: flex;
    align-items: center;
    gap: 10px;
  }
  .md-body h1 .accent { color: var(--blue); }
  .md-body .subtitle {
    font-size: 14px;
    color: var(--text-muted);
    margin-bottom: 20px;
    font-family: var(--mono);
  }
  .md-body p { margin-bottom: 12px; }
  .md-body p:last-child { margin-bottom: 0; }
  .md-body code {
    font-family: var(--mono);
    font-size: 13px;
    background: rgba(88,166,255,0.08);
    color: var(--blue);
    padding: 2px 6px;
    border-radius: 4px;
  }
  .md-body strong { color: var(--text); font-weight: 600; }
  .md-body ul {
    padding-left: 22px;
    margin-bottom: 12px;
  }
  .md-body li { margin-bottom: 5px; }
  .md-body li::marker { color: var(--cyan); }
  .md-body hr {
    border: none;
    border-top: 1px solid var(--border);
    margin: 18px 0;
  }

  .topic-grid {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 10px;
    margin-top: 16px;
  }
  .topic {
    background: rgba(88,166,255,0.04);
    border: 1px solid rgba(88,166,255,0.08);
    border-radius: 6px;
    padding: 10px 14px;
    font-size: 13px;
    display: flex;
    align-items: center;
    gap: 8px;
  }
  .topic .num {
    font-family: var(--mono);
    font-size: 10px;
    color: var(--purple);
    background: rgba(188,140,255,0.1);
    padding: 2px 7px;
    border-radius: 4px;
  }

  @media(max-width:600px) {
    .topic-grid { grid-template-columns: 1fr; }
  }
</style>
</head>
<body>
<div class="nb">

  <!-- Toolbar -->
  <div class="toolbar">
    <span class="filename">LinearAlgebra_Main.ipynb</span>
    <span class="kernel"><span class="dot"></span> Python 3 (ipykernel)</span>
  </div>

  <!-- Cell [1] — Markdown -->
  <div class="cell">
    <div class="cell-header">
      <span class="tag">MARKDOWN</span>
      <span class="run">✓ rendered</span>
    </div>
    <div class="md-body">
      <h1>📐 Linear Algebra <span class="accent">with Python</span></h1>
      <div class="subtitle">LinearAlgebra_Main &middot; NumPy &middot; SciPy</div>

      <p>This notebook covers the <strong>fundamentals of linear algebra</strong> implemented in Python using <code>numpy</code> and <code>numpy.linalg</code>. Each section builds on the last — from basic vector operations to matrix decompositions.</p>

      <hr>

      <p><strong>Prerequisites:</strong></p>
      <ul>
        <li>Python 3.8+ with <code>numpy</code> and <code>matplotlib</code> installed</li>
        <li>Basic familiarity with Python syntax</li>
      </ul>

      <p><strong>Topics covered:</strong></p>

      <div class="topic-grid">
        <div class="topic"><span class="num">01</span> Vectors &amp; Spaces</div>
        <div class="topic"><span class="num">02</span> Vector Operations</div>
        <div class="topic"><span class="num">03</span> Matrices &amp; Types</div>
        <div class="topic"><span class="num">04</span> Matrix Multiplication</div>
        <div class="topic"><span class="num">05</span> Transpose &amp; Inverse</div>
        <div class="topic"><span class="num">06</span> Determinants &amp; Rank</div>
        <div class="topic"><span class="num">07</span> Solving Ax = b</div>
        <div class="topic"><span class="num">08</span> Eigenvalues &amp; Eigenvectors</div>
        <div class="topic"><span class="num">09</span> SVD Decomposition</div>
        <div class="topic"><span class="num">10</span> Practical Applications</div>
      </div>
    </div>
  </div>

</div>
</body>
</html>
"""))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>LinearAlgebra_Main</title>
# <link href="https://fonts.googleapis.com/css2?family=IBM+Plex+Mono:wght@400;500;600&family=Source+Sans+3:wght@300;400;600&display=swap" rel="stylesheet">
# <style>
#   :root {
#     --bg: #0d1117;
#     --surface: #161b22;
#     --cell: #1c2128;
#     --border: #30363d;
#     --border-active: #58a6ff;
#     --text: #e6edf3;
#     --text-dim: #8b949e;
#     --text-muted: #484f58;
#     --blue: #58a6ff;
#     --green: #3fb950;
#     --purple: #bc8cff;
#     --orange: #d29922;
#     --red: #f85149;
#     --cyan: #39d2c0;
#     --mono: 'IBM Plex Mono', monospace;
#     --sans: 'Source Sans 3', sans-serif;
#   }
#   * { margin: 0; padding: 0; box-sizing: border-box; }
#   body { background: var(--bg); color: var(--text); font-family: var(--sans); }
#
#   .nb {
#     max-width: 900px;
#     margin: 0 auto;
# ...
