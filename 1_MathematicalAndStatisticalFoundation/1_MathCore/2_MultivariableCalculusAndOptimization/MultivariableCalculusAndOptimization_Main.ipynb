# %% [markdown]
# # 📈 Multivariable Calculus & Optimization with Python
# **MultivariableCalculusAndOptimization** · SymPy · SciPy · NumPy
#
# ---
#
# This notebook covers the **core concepts of multivariable calculus and optimization** implemented in Python. We move from partial derivatives and gradients through to real-world optimization techniques used in machine learning and engineering.
#
# ## Prerequisites
# - Python 3.8+ with `numpy`, `sympy`, `scipy`, and `matplotlib`
# - Basic single-variable calculus (derivatives, integrals)
# - Familiarity with vectors and matrices (see `LinearAlgebra_Main`)
#
# ---
#
# ## Topics Covered
#
# | # | Topic | Key Functions |
# |---|-------|---------------|
# | 01 | **Partial Derivatives** | `sympy.diff()`, `sympy.symbols()` |
# | 02 | **Gradients** | `np.gradient()`, symbolic grad |
# | 03 | **Directional Derivatives** | `np.dot(∇f, u)` |
# | 04 | **The Jacobian Matrix** | `sympy.Matrix().jacobian()` |
# | 05 | **The Hessian Matrix** | `sympy.hessian()` |
# | 06 | **Taylor Expansion (Multivar)** | `sympy.series()`, manual expansion |
# | 07 | **Unconstrained Optimization** | `scipy.optimize.minimize()` |
# | 08 | **Gradient Descent** | manual implementation |
# | 09 | **Constrained Optimization** | `scipy.optimize.minimize(constraints=)` |
# | 10 | **Lagrange Multipliers** | symbolic solve with `sympy` |
# | 11 | **Convexity & Saddle Points** | Hessian eigenvalue test |
# | 12 | **Practical Applications** | Curve fitting, loss surfaces, ML |
#
# ---
#
# ## Key Formulas
#
# **Gradient:**
#
# $$\nabla f(x, y) = \left( \frac{\partial f}{\partial x},\; \frac{\partial f}{\partial y} \right)$$
#
# **Directional Derivative:**
#
# $$D_{\vec{u}}\, f = \nabla f \cdot \vec{u}$$
#
# **Jacobian (vector-valued function):**
#
# $$J = \begin{bmatrix} \frac{\partial f_1}{\partial x_1} & \cdots & \frac{\partial f_1}{\partial x_n} \\ \vdots & \ddots & \vdots \\ \frac{\partial f_m}{\partial x_1} & \cdots & \frac{\partial f_m}{\partial x_n} \end{bmatrix}$$
#
# **Hessian:**
#
# $$H = \begin{bmatrix} \frac{\partial^2 f}{\partial x^2} & \frac{\partial^2 f}{\partial x \partial y} \\ \frac{\partial^2 f}{\partial y \partial x} & \frac{\partial^2 f}{\partial y^2} \end{bmatrix}$$
#
# **Gradient Descent Update Rule:**
#
# $$\vec{x}_{n+1} = \vec{x}_n - \alpha \, \nabla f(\vec{x}_n)$$
#
# **Lagrangian:**
#
# $$\mathcal{L}(x, y, \lambda) = f(x, y) - \lambda \, g(x, y)$$
#
# **Second Derivative Test (Multivar):**
#
# $$D = f_{xx} f_{yy} - (f_{xy})^2$$
# - $D > 0$ and $f_{xx} > 0$ → **local minimum**
# - $D > 0$ and $f_{xx} < 0$ → **local maximum**
# - $D < 0$ → **saddle point**
#
# ---
#
# > 💡 **Tip:** We use `sympy` for symbolic/exact math and `scipy.optimize` for numerical optimization. Run each cell in order with `Shift + Enter`.
